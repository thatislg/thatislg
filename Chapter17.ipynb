# %%
import pandas as pd
import psycopg2 as psy
import sqlalchemy # Thư viện dành cho hiển thị sql trong file

# %%
# Thông tin kết nối
"""
conn = psy.connect(
    host="153.92.214.210",
    database="er_sample",
    user="postgres",
    password="98919891",
    port="5432")
"""
# Out:
# '\nconn = psy.connect(\n    host="153.92.214.210",\n    database="er_sample",\n    user="postgres",\n    password="98919891",\n    port="5432")\n'

# %%
# Import thư viện kết nối với postgresql
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:98919891@153.92.214.210:5432/er_sample')

# %%
# Bắt đầu cho phép sử dụng sql trong dòng lệnh
# %reload_ext sql

# %%
# Khởi tạo kết nối với server database
# %sql postgresql://postgres:98919891@153.92.214.210:5432/er_sample

# %%
# %%sql
# SELECT
#     *
# FROM
#     book
# WHERE
#     category_id NOT IN(
#         SELECT
#             category_id
#         FROM
#             category
#         WHERE
#             LENGTH(category_name) <= 4
#     )
# ;
# # ｋｏｒｅｈａ ｎａｎｄｅｓｕｋａ
# Out:
#  * postgresql://postgres:***@153.92.214.210:5432/er_sample
# 35 rows affected.
# [('B0000001', '達人開発者', 3990, 390, 'C005', 'P0001', 333, '978-4894712740', datetime.date(2000, 11, 1)),
#  ('B0000002', 'Effective Ruby 第2版', 3780, 100, 'C005', 'P0001', 327, '978-4894714990', datetime.date(2008, 3, 31)),
#  ('B0000003', '真珠のプログラミング', 3570, 120, 'C005', 'P0001', 305, '978-4894712360', datetime.date(2000, 10, 1)),
#  ('B0000004', '満月の神話 新装版', 3360, 130, 'C005', 'P0001', 328, '978-4864010050', datetime.date(2010, 12, 1)),
#  ('B0000005', 'UNIXネットワークプログラム', 8400, 1200, 'C005', 'P0001', 978, '978-4894712050', datetime.date(1999, 7, 1)),
#  ('B0000007', '永遠の1', 920, 90, 'C001', 'P0002', 210, '978-4894712830', datetime.date(2010, 2, 1)),
#  ('B0000008', '生物と生物のあいだ', 777, 77, 'C001', 'P0002', 251, '978-4894713820', datetime.date(2011, 8, 15)),
#  ('B0000009', '世紀末の隣人', 580, 60, 'C003', 'P0002', 304, '978-4894717280', datetime.date(2007, 3, 1)),
#  ('B0000015', 'アインシュタイン16歳の現実', 819, 119, 'C003', 'P0004', 194, '978-4894712320', datetime.date(2007, 4, 1)),
#  ('B0000016', 'エジソン', 945, 105, 'C003', 'P0004', 210, None, datetime.date(1998, 2, 1)),
#  ('B0000014', '33歳のハローワーク', 600, 120, 'C003', None, 241, '978-4894012120', datetime.date(2007, 4, 1)),
#  ('B0000017', '冬のコナリ', 945, 105, 'C003', None, 326, '978-4894716210', datetime.date(2010, 1, 10)),
#  ('B0000006', '80歳を超えても30代に見える生き方', 920, 80, 'C001', 'P0002', None, None, datetime.date(2003, 3, 4)),
#  ('B0000022', 'アインシュタイン', 945, 105, 'C003', 'P0004', 221, None, datetime.date(1998, 2, 1)),
#  ('B0000023', '昨日の晩ごはん', 1679, 50, 'C001', 'P0002', 334, '978-4771278502', datetime.date(2011, 10, 31)),
#  ('B0000024', '一日一膳', 1680, 120, 'C003', 'P0001', 357, '978-4003512784', datetime.date(2010, 9, 15)),
#  ('B0000028', '頑張ればJava', 2000, 200, 'C005', 'P0005', 587, '978-4945413308', datetime.date(2012, 12, 29)),
#  ('B0000029', '明けの明星', 999, 150, 'C001', 'P0001', 319, '978-4733522781', datetime.date(2008, 2, 20)),
#  ('B0000030', 'より良い老後とは', 1200, 200, 'C003', 'P0004', 320, '978-4053520983', datetime.date(2006, 4, 11)),
#  ('B0000031', 'いつだってUML', 750, 30, 'C005', 'P0002', 299, '978-4669483725', datetime.date(2013, 8, 20)),
#  ('B0000032', 'からだのしくみ', 1000, 200, 'C003', 'P0003', 300, '978-4403549037', datetime.date(2011, 10, 16)),
#  ('B0000033', '楽しいプログラミング', 799, 80, 'C005', 'P0006', 180, '978-4351182793', datetime.date(2007, 3, 31)),
#  ('B0000035', '深海のシーラカンス', 799, 90, 'C001', 'P0002', 333, '978-4353577795', datetime.date(2007, 4, 1)),
#  ('B0000038', '恋のサブリミナル', 800, 150, 'C001', 'P0005', 399, '978-4983779811', datetime.date(2008, 3, 31)),
#  ('B0000040', 'バスケがしたいです', 800, 130, 'C003', 'P0006', 177, '978-4567890123', datetime.date(2008, 4, 1)),
#  ('B0000041', '雨雲', 1580, 100, 'C001', 'P0001', 299, '978-4987654321', datetime.date(2010, 9, 23)),
#  ('B0000042', '週末のオブジェクト指向クラブ', 2500, 100, 'C005', 'P0003', 300, '978-4102938475', datetime.date(2009, 9, 1)),
#  ('B0000044', '一子相伝の極み', 689, 101, 'C003', 'P0005', 300, '978-4135790864', datetime.date(2010, 7, 2)),
#  ('B0000046', '永遠の向こう側', 800, 130, 'C001', 'P0002', 235, '978-4291038476', datetime.date(2009, 5, 5)),
#  ('B0000047', 'みんなでクラウド', 2999, 499, 'C005', 'P0004', 405, '978-4852146097', datetime.date(2006, 8, 24)),
#  ('B0000049', '秘伝のタレ 新版', 3999, 199, 'C003', 'P0003', 555, '978-4098760982', datetime.date(2002, 2, 22)),
#  ('B0000051', '思い出のHTML', 1690, 90, 'C005', 'P0001', 249, '978-4765921092', datetime.date(2008, 8, 7)),
#  ('B0000052', '止まらない世界', 4100, 350, 'C003', 'P0004', 250, '978-4238764901', datetime.date(2010, 10, 10)),
#  ('B0000053', 'ららら', 2000, 200, 'C001', 'P0002', 299, '978-4983740208', datetime.date(2009, 9, 15)),
#  ('B0000056', '湯けむりの嗜み', 999, 49, 'C001', 'P0001', 300, '978-4769802134', datetime.date(2010, 9, 15))]

# %%
teset tw cs
# Out:
#   Input In [11]
#     teset tw cs
#           ^
# SyntaxError: invalid syntax
